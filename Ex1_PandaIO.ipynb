# %%
import pandas as pd

# %%
url1 = 'https://raw.githubusercontent.com/alura-cursos/Pandas/refs/heads/main/superstore_data_ponto_virgula.csv'

# %%
dados = pd.read_csv(url1, sep=';', nrows=5, usecols=[0,1,4])
dados
# Out:
#       Id  Year_Birth  Income
# 0   1826        1970   84835
# 1      1        1961   57091
# 2  10476        1958   67267
# 3   1386        1967   32474
# 4   5371        1989   21474

# %%
url2 = 'https://raw.githubusercontent.com/alura-cursos/Pandas/refs/heads/main/superstore_data.csv'

# %%
df = pd.read_csv(url2, usecols=[0,1,4])
df
# Out:
#          Id  Year_Birth   Income
# 0      1826        1970  84835.0
# 1         1        1961  57091.0
# 2     10476        1958  67267.0
# 3      1386        1967  32474.0
# 4      5371        1989  21474.0
# ...     ...         ...      ...
# 2235  10142        1976  66476.0
# 2236   5263        1977  31056.0
# 2237     22        1976  46310.0
# 2238    528        1978  65819.0
# 2239   4070        1969  94871.0
#
# [2240 rows x 3 columns]

# %%
df.to_csv('dados_mercado.csv', index=False)

# %%
pd.read_csv('dados_mercado.csv')
# Out:
#          Id  Year_Birth   Income
# 0      1826        1970  84835.0
# 1         1        1961  57091.0
# 2     10476        1958  67267.0
# 3      1386        1967  32474.0
# 4      5371        1989  21474.0
# ...     ...         ...      ...
# 2235  10142        1976  66476.0
# 2236   5263        1977  31056.0
# 2237     22        1976  46310.0
# 2238    528        1978  65819.0
# 2239   4070        1969  94871.0
#
# [2240 rows x 3 columns]
